# %%
import os
import sys

sys.path.insert(0, os.getcwd())

# %%
from snscrape_lib import Twitter
from datetime import date
import pandas as pd

# %%
df = Twitter.query_hashtag("Shibainu", limit=10)

df.to_csv("scraper_test.csv")
# Out:
# Found <bound method DataFrame.count of                     id                        date          username  \
# 0  1471820463450034184   2021-12-17 12:31:58+00:00    iamwilliamcoit
# 1  1471820239100776448   2021-12-17 12:31:04+00:00   UnitedIndians47
# 2  1471820149430923266   2021-12-17 12:30:43+00:00   amirchalesh1368
# 3  1471820129419898882   2021-12-17 12:30:38+00:00     CheemsInuArmy
# 4  1471819920921042945   2021-12-17 12:29:48+00:00      Pegaso121080
# 5  1471819674547462149   2021-12-17 12:28:50+00:00         shingatok
# 6  1471819278701805579   2021-12-17 12:27:15+00:00   Shib_xWarrior29
# 7  1471819110379974656   2021-12-17 12:26:35+00:00   ADITYAK66583044
# 8  1471819103396581384   2021-12-17 12:26:33+00:00   o8U1XV8k9VZ41Ub
# 9  1471818899914211329   2021-12-17 12:25:45+00:00        Audioguy16
#
#                                              content  \
# 0   "'$shib to .0001 before the end of the year \...
# 1   "'@askthedr @Shibtoken \n\nToo disappointed w...
# ...

# %%
pd.read_csv("scraper_test.csv")
# Out:
#    Unnamed: 0                   id                        date  \
# 0           0  1471820463450034184   2021-12-17 12:31:58+00:00
# 1           1  1471820239100776448   2021-12-17 12:31:04+00:00
# 2           2  1471820149430923266   2021-12-17 12:30:43+00:00
# 3           3  1471820129419898882   2021-12-17 12:30:38+00:00
# 4           4  1471819920921042945   2021-12-17 12:29:48+00:00
# 5           5  1471819674547462149   2021-12-17 12:28:50+00:00
# 6           6  1471819278701805579   2021-12-17 12:27:15+00:00
# 7           7  1471819110379974656   2021-12-17 12:26:35+00:00
# 8           8  1471819103396581384   2021-12-17 12:26:33+00:00
# 9           9  1471818899914211329   2021-12-17 12:25:45+00:00
#
#            username                                            content  \
# 0    iamwilliamcoit   "'$shib to .0001 before the end of the year \...
# 1   UnitedIndians47   "'@askthedr @Shibtoken \n\nToo disappointed w...
# ...
